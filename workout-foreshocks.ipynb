# %%
# The empirical Bath's law states that the average difference in magnitude 
# between a mainshock and its largest aftershock is 1.2, 
# regardless of the mainshock magnitude.

import src.aftershocks as shocks

# %%
M = 8.0
lon, lat, dep = 30, 15, 20

from datetime import datetime 

date = datetime(2020, 5, 17)

M_fs, lon_fs, lat_fs, dep_fs, dates_fs = shocks.get_foreshocks(M, lon, lat, dep, date, doplot=True)

print(M_fs, dates_fs)
# Out:
# [5.29, 5.31, 6.65] [datetime.datetime(2020, 4, 29, 15, 31, 14, 338644), datetime.datetime(2020, 5, 7, 18, 42, 32, 337795), datetime.datetime(2020, 5, 9, 17, 27, 48, 21666)]
